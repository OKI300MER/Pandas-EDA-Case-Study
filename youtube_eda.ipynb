# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, time, timezone,date

# %%
pwd
# Out:
# 'c:\\Users\\shric\\Desktop\\Dai\\assignments\\eda assignment\\Pandas-EDA-Case-Study'

# %%
#dataset of Trending YouTube Video Statistics
video_stats_df = pd.read_csv(r'C:\Users\shric\Desktop\Dai\assignments\eda assignment\Pandas-EDA-Case-Study\USvideos.csv')
#video_stats_df.sample(20)

# %%
video_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
# ...

# %%
video_stats_df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
video_stats_df['trending_date'] = pd.to_datetime(video_stats_df['trending_date'], format="%y.%d.%m")
video_stats_df['publish_time'] = pd.to_datetime(video_stats_df['publish_time'])

print(video_stats_df.head())
print(video_stats_df.info())
print(video_stats_df.describe())
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
# 4  d380meD0W0M    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22 2017-11-13 17:13:01+00:00
# 1           24 2017-11-13 07:30:00+00:00
# 2           23 2017-11-12 19:05:24+00:00
# 3           24 2017-11-13 11:00:04+00:00
# 4           24 2017-11-12 18:01:41+00:00
#
# ...

# %%
video_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  datetime64[ns]
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  datetime64[ns, UTC]
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
# ...

# %%
#sns.barplot(video_stats_df)
plt.xticks(rotation = 90);

# %%
#sns.scatterplot(data = (video_stats_df['likes'],['dislikes']))
plt.title('Daily User Likes')
plt.xlabel('Likes')
plt.ylabel('Dislikes')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
video_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  datetime64[ns]
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  datetime64[ns, UTC]
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
# ...

# %%
#sns.scatterplot(data = video_stats_df, x = 'comment_count',y = 'likes')
#plt.bar(video_stats_df['comment_count'], video_stats_df['likes'])
plt.title('Likes to Comments')
plt.xlabel('Likes')
plt.ylabel('comment count')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#sns.pairplot(video_stats_df)

# %%
#sns.scatterplot(data = video_stats_df, x = 'dislikes',y = 'likes')
#plt.bar(video_stats_df['comment_count'], video_stats_df['likes'])
plt.title('Likes to Comments')
plt.xlabel('Likes')
plt.ylabel('dislikes')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#sns.scatterplot(data = video_stats_df, x = 'views',y = 'dislikes')
#plt.bar(video_stats_df['comment_count'], video_stats_df['likes'])
plt.title('Dislikes to views')
plt.xlabel('Dislikes')
plt.ylabel('views')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
video_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  datetime64[ns]
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  datetime64[ns, UTC]
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
# ...

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data = video_stats_df,x='trending_date', y='likes', color='blue', label='Likes')
sns.scatterplot(data = video_stats_df, x='trending_date', y='dislikes', color='red', label='Dislikes')

plt.title('Dislikes to views')
plt.xlabel('Trending Date')
plt.ylabel('likes/ dislikes')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(data = video_stats_df,x='publish_time', y='likes', color='blue', label='Likes')
sns.scatterplot(data = video_stats_df, x='publish_time', y='dislikes', color='red', label='Dislikes')

plt.title('Dislikes to views')
plt.xlabel('Published Date')
plt.ylabel('likes/ dislikes')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
#group by index of columns. 

video_stats_df['year'] = video_stats_df['publish_time'].dt.year
video_stats_df['date_only'] = pd.to_datetime(video_stats_df['publish_time']).dt.tz_localize(None)
grouped_years =  video_stats_df.groupby('year').sum(numeric_only = True)



plt.figure(figsize=(10, 6))
sns.boxplot(grouped_years)

#plt.title('Dislikes to views')
#plt.xlabel('Published Date')
#plt.ylabel('likes/ dislikes')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()
video_stats_df.info()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  datetime64[ns]
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  datetime64[ns, UTC]
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
# ...

# %%
certain_datetime = ('2017-2-1')
year_df = video_stats_df[video_stats_df['date_only'] >= certain_datetime]


year_df.value_counts('date_only', ascending= True)

by_date_df = year_df.sort_values(by = 'date_only', ascending= True)
by_date_df.head()
# Out:
#           video_id trending_date                                       title  \
# 11567  kjkw7rKhPfc    2018-01-12                        PK Inventor ASM V1 0
# 13352  FvLdEZ3mg54    2018-01-21  1992 Skin Bracer commercial w/Jack Palance
# 13582  FvLdEZ3mg54    2018-01-22  1992 Skin Bracer commercial w/Jack Palance
# 13134  FvLdEZ3mg54    2018-01-20  1992 Skin Bracer commercial w/Jack Palance
# 12908  FvLdEZ3mg54    2018-01-19  1992 Skin Bracer commercial w/Jack Palance
#
#               channel_title  category_id              publish_time  \
# 11567           PK Inventor           28 2017-02-10 22:20:03+00:00
# 13352  gamelovercommercials           24 2017-02-18 15:21:10+00:00
# 13582  gamelovercommercials           24 2017-02-18 15:21:10+00:00
# 13134  gamelovercommercials           24 2017-02-18 15:21:10+00:00
# 12908  gamelovercommercials           24 2017-02-18 15:21:10+00:00
#
#                                                     tags  views  likes  \
# ...

# %%
last_trending_date_df = video_stats_df.groupby('video_id')['views'].max().reset_index()
by_date_df
# Out:
#           video_id trending_date  \
# 11567  kjkw7rKhPfc    2018-01-12
# 13352  FvLdEZ3mg54    2018-01-21
# 13582  FvLdEZ3mg54    2018-01-22
# 13134  FvLdEZ3mg54    2018-01-20
# 12908  FvLdEZ3mg54    2018-01-19
# ...            ...           ...
# 40761  JGm9Y_hFqNk    2018-06-14
# 40756  MrMAfMbZOmg    2018-06-14
# 40755  -9rdDeWzvsU    2018-06-14
# 40759  Gi56dSh8Fq8    2018-06-14
# 40751  8O-ZUXGcuWU    2018-06-14
#
#                                                    title  \
# 11567                               PK Inventor ASM V1 0
# 13352         1992 Skin Bracer commercial w/Jack Palance
# 13582         1992 Skin Bracer commercial w/Jack Palance
# 13134         1992 Skin Bracer commercial w/Jack Palance
# 12908         1992 Skin Bracer commercial w/Jack Palance
# ...                                                  ...
# 40761  First Take reacts: Kyrie Irving says contract ...
# 40756  Troye Sivan - Dance To This (Official Audio) f...
# ...

# %%
max_views_row = by_date_df.loc[by_date_df['views'].idxmax()]
max_views_row
# Out:
# video_id                                                        VYOjWnS4cMY
# trending_date                                           2018-06-02 00:00:00
# title                     Childish Gambino - This Is America (Official V...
# channel_title                                           ChildishGambinoVEVO
# category_id                                                              10
# publish_time                                      2018-05-06 04:00:07+00:00
# tags                      Childish Gambino|"Rap"|"This Is America"|"mcDJ...
# views                                                             225211923
# likes                                                               5023450
# dislikes                                                             343541
# comment_count                                                        517232
# thumbnail_link               https://i.ytimg.com/vi/VYOjWnS4cMY/default.jpg
# ...

# %%
"""
Bar Chart of View Count Over Time:
Visualize the trend of view counts for videos over time.
Each bar represents a specific time period (e.g., daily, weekly, monthly).
This chart helps to identify periods of high and low viewership and assess the overall popularity trend.

"""
fig, ax = plt.subplots()
ax.bar(x = 'date_only', height = 'views', data = by_date_df)
plt.title('Views Over Time by Dates')
plt.xlabel('Dates 2017 - 2018')
plt.ylabel('Video Views (In Millions)')
plt.xticks(rotation=45)
plt.legend()
plt.show();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
"""
Scatter Plot of Comment Count vs. View Count:
Plot the number of comments against the view count for each video.
Each point represents a video, and its position reflects both the view count and comment count.
This plot helps to understand the relationship between viewer engagement (comments) and video popularity (view count).

"""

sns.scatterplot(data = by_date_df, x = "views", y = "comment_count")
plt.title('Comments Against the View Count')
plt.xlabel('Views (In Millions)')
plt.ylabel('Comment Counts (In Millions)')
plt.xticks(rotation=0)
plt.legend()
plt.tight_layout()
plt.show();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
"""
Line Chart of Trending Date:
Plot the number of videos trending on each date over time.
Use a line chart to show the trend of video trending dates.
This chart helps to track the frequency of videos trending on YouTube and identify any patterns or fluctuations.

"""
by_date_df["day"] = pd.to_datetime(by_date_df["date_only"]).dt.day
by_date_df["month"] = pd.to_datetime(by_date_df["date_only"]).dt.month

sns.lineplot(data = by_date_df, x = "month", y = "views")
plt.title('Trending Videos by Month')
plt.xlabel('Month')
plt.ylabel('Video Views (In Millions)')
plt.xticks(rotation=0)
plt.legend()
plt.tight_layout()
plt.show();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.lineplot(data = by_date_df, x = "day", y = "views")
plt.title('Trending Videos by Day')
plt.xlabel('Day of Month')
plt.ylabel('Video Views (In Millions)')
plt.xticks(rotation=0)
plt.legend()
plt.tight_layout()
plt.show();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
"""
Heatmap of Engagement Metrics:
Create a heatmap to visualize the correlation between engagement metrics (view count, likes, dislikes, comment count).
Each cell in the heatmap represents the correlation coefficient between two metrics.
This visualization provides insights into how different engagement metrics relate to each other and can help identify which metrics have the strongest correlation.
select_dtypes(include=['int64', 'float64'])
"""
only_nums_df = by_date_df.loc[:, ["views", "likes", "dislikes", "comment_count"]]
sns.heatmap(only_nums_df.corr(), annot=True,
            cmap="inferno",
            vmin = -0.5,
            vmax = 1)
plt.title('Correlation Between Engagement Metrics')
plt.legend()
plt.tight_layout()
plt.show();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
