# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, time, timezone,date

# %%
pwd
# Out:
# '/Users/brandoncooke/Public/galvanize/Case_study/Pandas-EDA-Case-Study'

# %%
#dataset of Trending YouTube Video Statistics
video_stats_df = pd.read_csv('USvideos.csv')
video_stats_df.sample(20)
# Out:
#           video_id trending_date  \
# 28313  hDEc4ImIVHk      18.06.04
# 10921  UQtt9I6c-YM      18.07.01
# 166    5Smb3tZD1Qc      17.14.11
# 36075  beb8zCGMsbI      18.21.05
# 17755  qUmfriZoMw0      18.12.02
# 13091  LHLbPgXPnlk      18.20.01
# 39931  MAjY8mCTXWk      18.09.06
# 6290   _JhaVNJb3ag      17.15.12
# 27026  bweX9_u7S0Y      18.31.03
# 10011  Aj5oA0YxCi0      18.03.01
# 4681   spuXN0ccRQ8      17.07.12
# 39476  UKserM-i0_A      18.07.06
# 37739  Of9GOMM9HPg      18.29.05
# 14029  uGwcNjWrgaU      18.25.01
# 22030  kton-qrKNLc      18.06.03
# 31699  tyjVu_IFKMc      18.29.04
# 37168  kFMZUxX6K6o      18.27.05
# 12645  ForvnkfjtpY      18.18.01
# 34791  CPjWgk0UXps      18.15.05
# 40415  _BcYBFC6zfY      18.12.06
#
#                                                    title  \
# 28313  Emma Gonzalez gives speech at March for Our Li...
# 10921                        Kramer vs Kramer-Clou Scene
# 166       Tamar Braxton Talks Divorce In First Interview
# 36075  James Veitch’s Elaborate Wrong Number Prank  -...
# 17755  Westworld Season 2 | Official Super Bowl LII A...
# 13091  Ned Price Says CIA Officer Arrest Is As Seriou...
# 39931  周杰倫 Jay Chou【不愛我就拉倒 If You Don't Love Me, It's...
# 6290   Heart-Wrenching Video: Starving Polar Bear on ...
# 27026  First Take debates impact of Steph Curry and K...
# 10011  The Link Between Japanese Samurai and Real Indigo
# 4681                  SHOCKING Science with a Leyden Jar
# 39476            Panic! At The Disco: High Hopes (Audio)
# 37739                                      Nintendo Labo
# 14029                         Why Are Fat People a Joke?
# 22030                        Meghan Trainor - No Excuses
# 31699                 Lauryn Hill: 20 Years Of Relevance
# 37168  Live It Up - Nicky Jam feat. Will Smith & Era ...
# 12645  Why Does Getting Water Up Your Nose Hurt So Much?
# 34791        I Got My Apartment Professionally Organized
# 40415  Ralph Breaks the Internet: Wreck-It Ralph 2 Of...
#
#                        channel_title  category_id              publish_time  \
# 28313                            CNN           25  2018-03-24T19:16:38.000Z
# 10921              Livia Giustiniani            1  2008-04-05T18:22:40.000Z
# 166                 Tamar Chronicles           24  2017-11-08T18:00:00.000Z
# 36075                      Team Coco           23  2018-05-10T01:57:54.000Z
# 17755                            HBO            1  2018-02-05T02:01:07.000Z
# 13091                          MSNBC           25  2018-01-17T21:16:51.000Z
# 39931                杰威爾音樂 JVR Music           10  2018-05-14T15:59:47.000Z
# 6290             National Geographic           15  2017-12-11T18:00:02.000Z
# 27026                           ESPN           17  2018-03-26T14:30:58.000Z
# 10011                Great Big Story           22  2018-01-02T07:00:01.000Z
# 4681              The King of Random           27  2017-12-03T15:00:03.000Z
# 39476            Panic! At The Disco           10  2018-05-23T18:00:13.000Z
# 37739                videogamedunkey           20  2018-05-06T19:30:01.000Z
# 14029                       LoeyLane           24  2018-01-23T14:00:04.000Z
# 22030              MeghanTrainorVEVO           10  2018-03-01T13:00:05.000Z
# 31699                    Nerdwriter1           24  2018-04-18T14:00:05.000Z
# 37168                     NickyJamTV           10  2018-05-25T04:00:21.000Z
# 12645                        SciShow           27  2018-01-16T22:00:00.000Z
# 34791                 Michelle Khare           24  2018-05-11T15:00:01.000Z
# 40415  Walt Disney Animation Studios            1  2018-06-04T16:00:03.000Z
#
#                                                     tags     views   likes  \
# 28313  latest News|"Happening Now"|"CNN"|"us news"|"p...    905745   19277
# 10921  Meryl|"Streep"|"kramer"|"vs"|"dustin"|"hoffman...     50030      46
# 166    tamar|"tamar braxton"|"tamar braxton vince her...    451356    3454
# 36075  Conan O'Brien Conan Conan (TV Series) TBS (TV ...   1700548   50343
# 17755  HBO|"Westworld"|"Evan Rachel Wood"|"JJ Abrams"...  11358208   39601
# 13091  MSNBC|"news channel"|"news station"|"newspaper...     51404     396
# 39931  周杰倫|"Jay"|"Chou"|"周董"|"周杰伦"|"周傑倫"|"杰威尔"|"周周"|"...  21173273  138996
# 6290   national geographic|"nat geo"|"natgeo"|"animal...    691217   11522
# 27026  stephen curry|"steph curry"|"kyrie irving"|"es...    444092    3240
# 10011  great big story|"gbs"|"lag"|"documentary"|"doc...    130531    5336
# 4681   leyden jar|"leyden"|"jar"|"electric"|"electric...    861030   18597
# 39476  Panic At The Disco|"Panic! At The Disco"|"PATD...   4947674  207196
# 37739  dunkey|"videogamedunkey"|"nintendo labo"|"dunk...   2687493  131699
# 14029  loeylane|"loey lane"|"loey"|"bug"|"lane"|"loey...    221587       0
# 22030  meghan trainor|"no excuses"|"no excuses offici...   6478495  232625
# 31699  the nerdwriter|"nerdwriter"|"nerdwriter youtub...    284674   30378
# 37168  Nicky Jam|"NickyJamPR"|"latin"|"will smith"|"E...   6536770  154108
# 12645  SciShow|"science"|"Hank"|"Green"|"education"|"...    187092    7772
# 34791  michelle khare|"buzzfeed michelle"|"organize"|...   1122213   28049
# 40415  Disney|"Walt Disney Animation Studios"|"Disney...  12367711  215332
#
#        dislikes  comment_count  \
# 28313     31630          32911
# 10921         6             26
# 166         284            623
# 36075       784            789
# 17755      1355           2778
# 13091        32            240
# 39931     10565          15360
# 6290       1699           5111
# 27026       229           1154
# 10011        64            283
# 4681       1196           3500
# 39476      2288          21937
# 37739      5144           9119
# 14029         0           3663
# 22030     19400          17756
# 31699       634           2212
# 37168     29352          23249
# 12645        88            591
# 34791      1299           1214
# 40415     13122          38960
#
#                                        thumbnail_link  comments_disabled  \
# 28313  https://i.ytimg.com/vi/hDEc4ImIVHk/default.jpg              False
# 10921  https://i.ytimg.com/vi/UQtt9I6c-YM/default.jpg              False
# 166    https://i.ytimg.com/vi/5Smb3tZD1Qc/default.jpg              False
# 36075  https://i.ytimg.com/vi/beb8zCGMsbI/default.jpg              False
# 17755  https://i.ytimg.com/vi/qUmfriZoMw0/default.jpg              False
# 13091  https://i.ytimg.com/vi/LHLbPgXPnlk/default.jpg              False
# 39931  https://i.ytimg.com/vi/MAjY8mCTXWk/default.jpg              False
# 6290   https://i.ytimg.com/vi/_JhaVNJb3ag/default.jpg              False
# 27026  https://i.ytimg.com/vi/bweX9_u7S0Y/default.jpg              False
# 10011  https://i.ytimg.com/vi/Aj5oA0YxCi0/default.jpg              False
# 4681   https://i.ytimg.com/vi/spuXN0ccRQ8/default.jpg              False
# 39476  https://i.ytimg.com/vi/UKserM-i0_A/default.jpg              False
# 37739  https://i.ytimg.com/vi/Of9GOMM9HPg/default.jpg              False
# 14029  https://i.ytimg.com/vi/uGwcNjWrgaU/default.jpg              False
# 22030  https://i.ytimg.com/vi/kton-qrKNLc/default.jpg              False
# 31699  https://i.ytimg.com/vi/tyjVu_IFKMc/default.jpg              False
# 37168  https://i.ytimg.com/vi/kFMZUxX6K6o/default.jpg              False
# 12645  https://i.ytimg.com/vi/ForvnkfjtpY/default.jpg              False
# 34791  https://i.ytimg.com/vi/CPjWgk0UXps/default.jpg              False
# 40415  https://i.ytimg.com/vi/_BcYBFC6zfY/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 28313             False                   False
# 10921             False                   False
# 166               False                   False
# 36075             False                   False
# 17755             False                   False
# 13091             False                   False
# 39931             False                   False
# 6290              False                   False
# 27026             False                   False
# 10011             False                   False
# 4681              False                   False
# 39476             False                   False
# 37739             False                   False
# 14029              True                   False
# 22030             False                   False
# 31699             False                   False
# 37168             False                   False
# 12645             False                   False
# 34791             False                   False
# 40415             False                   False
#
#                                              description
# 28313  Speaking at the March for Our Lives event in W...
# 10921               Poor Meryl...she was really scaredxD
# 166    In Tamar Braxton's first interview to promote ...
# 36075  CONAN Highlight: When a man confused James for...
# 17755  A new chapter begins.\n \nWatch the official S...
# 13091  Former CIA officer Jerry Chun Shing Lee was ar...
# 39931  詞：周杰倫、宋健彰（彈頭）  曲：周杰倫MV導演：周杰倫憂鬱型男的走心旋律  用英式搖滾宣洩...
# 6290   This is what climate change looks like. This s...
# 27026  First Take's Stephen A. Smith and Max Kellerma...
# 10011  Real indigo-dyed clothing is not like the blue...
# 4681   Get your very own TKOR Official T-Shirt, only ...
# 39476  I spent too long not setting my expectations h...
# 37739  Say goodbye to virtual reality. Say hello to r...
# 14029  OPEN ME FOR ALL OF THE THINGS!\n\nWatch Meghan...
# 22030  No Excuses available at Spotify: http://smartu...
# 31699  A mini-doc exploring the impact and influence ...
# 37168  Nicky Jam feat. Will Smith & Era Istrefi - Liv...
# 12645  Jumping into a refreshingly cold body of water...
# 34791  I worked with professional organizer Ashley Mo...
# 40415  Watch the official trailer for Ralph Breaks th...

# %%
pwd
# Out:
# '/Users/brandoncooke/Public/galvanize/Case_study/Pandas-EDA-Case-Study'

# %%
video_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %%
video_stats_df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
video_stats_df['trending_date'] = pd.to_datetime(video_stats_df['trending_date'], format="%y.%d.%m")
video_stats_df['publish_time'] = pd.to_datetime(video_stats_df['publish_time'])

print(video_stats_df.head())
print(video_stats_df.info())
print(video_stats_df.describe())
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
# 4  d380meD0W0M    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22 2017-11-13 17:13:01+00:00
# 1           24 2017-11-13 07:30:00+00:00
# 2           23 2017-11-12 19:05:24+00:00
# 3           24 2017-11-13 11:00:04+00:00
# 4           24 2017-11-12 18:01:41+00:00
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  Today we find out if Link is a Nickelback amat...
# 4  I know it's been a while since we did this sho...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  datetime64[ns]
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  datetime64[ns, UTC]
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  object
# dtypes: bool(3), datetime64[ns, UTC](1), datetime64[ns](1), int64(5), object(6)
# memory usage: 4.2+ MB
# None
#                        trending_date   category_id         views  \
# count                          40949  40949.000000  4.094900e+04
# mean   2018-02-27 06:22:42.494810624     19.972429  2.360785e+06
# min              2017-11-14 00:00:00      1.000000  5.490000e+02
# 25%              2018-01-04 00:00:00     17.000000  2.423290e+05
# 50%              2018-02-26 00:00:00     24.000000  6.818610e+05
# 75%              2018-04-24 00:00:00     25.000000  1.823157e+06
# max              2018-06-14 00:00:00     43.000000  2.252119e+08
# std                              NaN      7.568327  7.394114e+06
#
#               likes      dislikes  comment_count
# count  4.094900e+04  4.094900e+04   4.094900e+04
# mean   7.426670e+04  3.711401e+03   8.446804e+03
# min    0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.424000e+03  2.020000e+02   6.140000e+02
# 50%    1.809100e+04  6.310000e+02   1.856000e+03
# 75%    5.541700e+04  1.938000e+03   5.755000e+03
# max    5.613827e+06  1.674420e+06   1.361580e+06
# std    2.288853e+05  2.902971e+04   3.743049e+04

# %%
video_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  datetime64[ns]
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  datetime64[ns, UTC]
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  object
# dtypes: bool(3), datetime64[ns, UTC](1), datetime64[ns](1), int64(5), object(6)
# memory usage: 4.2+ MB

# %%
sns.barplot(video_stats_df)
plt.xticks(rotation = 90);

# %%
sns.scatterplot(data = (video_stats_df['likes'],['dislikes']))
plt.title('Daily User Likes')
plt.xlabel('Likes')
plt.ylabel('Dislikes')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
video_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  datetime64[ns]
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  datetime64[ns, UTC]
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  object
# dtypes: bool(3), datetime64[ns, UTC](1), datetime64[ns](1), int64(5), object(6)
# memory usage: 4.2+ MB

# %%
sns.scatterplot(data = video_stats_df, x = 'comment_count',y = 'likes')
#plt.bar(video_stats_df['comment_count'], video_stats_df['likes'])
plt.title('Likes to Comments')
plt.xlabel('Likes')
plt.ylabel('comment count')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.pairplot(video_stats_df)

# %%
sns.scatterplot(data = video_stats_df, x = 'dislikes',y = 'likes')
#plt.bar(video_stats_df['comment_count'], video_stats_df['likes'])
plt.title('Likes to Comments')
plt.xlabel('Likes')
plt.ylabel('dislikes')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.scatterplot(data = video_stats_df, x = 'views',y = 'dislikes')
#plt.bar(video_stats_df['comment_count'], video_stats_df['likes'])
plt.title('Dislikes to views')
plt.xlabel('Dislikes')
plt.ylabel('views')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
video_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  datetime64[ns]
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  datetime64[ns, UTC]
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  object
# dtypes: bool(3), datetime64[ns, UTC](1), datetime64[ns](1), int64(5), object(6)
# memory usage: 4.2+ MB

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data = video_stats_df,x='trending_date', y='likes', color='blue', label='Likes')
sns.scatterplot(data = video_stats_df, x='trending_date', y='dislikes', color='red', label='Dislikes')

plt.title('Dislikes to views')
plt.xlabel('Trending Date')
plt.ylabel('likes/ dislikes')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(data = video_stats_df,x='publish_time', y='likes', color='blue', label='Likes')
sns.scatterplot(data = video_stats_df, x='publish_time', y='dislikes', color='red', label='Dislikes')

plt.title('Dislikes to views')
plt.xlabel('Published Date')
plt.ylabel('likes/ dislikes')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
#group by index of columns. 

video_stats_df['year'] = video_stats_df['publish_time'].dt.year
video_stats_df['date_only'] = pd.to_datetime(video_stats_df['publish_time']).dt.tz_localize(None)
grouped_years =  video_stats_df.groupby('year').sum(numeric_only = True)



plt.figure(figsize=(10, 6))
sns.boxplot(grouped_years)

#plt.title('Dislikes to views')
#plt.xlabel('Published Date')
#plt.ylabel('likes/ dislikes')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()
video_stats_df.info()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  datetime64[ns]
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  datetime64[ns, UTC]
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  object
#  16  year                    40949 non-null  int32
#  17  date_only               40949 non-null  datetime64[ns]
# dtypes: bool(3), datetime64[ns, UTC](1), datetime64[ns](2), int32(1), int64(5), object(6)
# memory usage: 4.6+ MB

# %%
certain_datetime = ('2017-01-01')
year_df = video_stats_df[video_stats_df['date_only'] >= certain_datetime]

year_df.value_counts('date_only', ascending= True)



by_date_df = year_df.sort_values(by = 'date_only', ascending= True)
by_date_df.head()
# Out:
#           video_id trending_date                                       title  \
# 11567  kjkw7rKhPfc    2018-01-12                        PK Inventor ASM V1 0
# 13352  FvLdEZ3mg54    2018-01-21  1992 Skin Bracer commercial w/Jack Palance
# 13582  FvLdEZ3mg54    2018-01-22  1992 Skin Bracer commercial w/Jack Palance
# 13134  FvLdEZ3mg54    2018-01-20  1992 Skin Bracer commercial w/Jack Palance
# 12908  FvLdEZ3mg54    2018-01-19  1992 Skin Bracer commercial w/Jack Palance
#
#               channel_title  category_id              publish_time  \
# 11567           PK Inventor           28 2017-02-10 22:20:03+00:00
# 13352  gamelovercommercials           24 2017-02-18 15:21:10+00:00
# 13582  gamelovercommercials           24 2017-02-18 15:21:10+00:00
# 13134  gamelovercommercials           24 2017-02-18 15:21:10+00:00
# 12908  gamelovercommercials           24 2017-02-18 15:21:10+00:00
#
#                                                     tags  views  likes  \
# 11567  e-mobility|"transport"|"logistics"|"robotics"|...   5509      0
# 13352  skin bracer|"commercial"|"june"|"1992"|"jack p...  22707    365
# 13582  skin bracer|"commercial"|"june"|"1992"|"jack p...  22768    365
# 13134  skin bracer|"commercial"|"june"|"1992"|"jack p...  22581    365
# 12908  skin bracer|"commercial"|"june"|"1992"|"jack p...  22264    365
#
#        dislikes  comment_count  \
# 11567         0             17
# 13352        64            203
# 13582        64            204
# 13134        64            203
# 12908        63            203
#
#                                        thumbnail_link  comments_disabled  \
# 11567  https://i.ytimg.com/vi/kjkw7rKhPfc/default.jpg              False
# 13352  https://i.ytimg.com/vi/FvLdEZ3mg54/default.jpg              False
# 13582  https://i.ytimg.com/vi/FvLdEZ3mg54/default.jpg              False
# 13134  https://i.ytimg.com/vi/FvLdEZ3mg54/default.jpg              False
# 12908  https://i.ytimg.com/vi/FvLdEZ3mg54/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 11567              True                   False
# 13352             False                   False
# 13582             False                   False
# 13134             False                   False
# 12908             False                   False
#
#                                              description  year  \
# 11567  Invention in the field of transport, robotics,...  2017
# 13352  The actor promotes the aftershave in this quic...  2017
# 13582  The actor promotes the aftershave in this quic...  2017
# 13134  The actor promotes the aftershave in this quic...  2017
# 12908  The actor promotes the aftershave in this quic...  2017
#
#                 date_only
# 11567 2017-02-10 22:20:03
# 13352 2017-02-18 15:21:10
# 13582 2017-02-18 15:21:10
# 13134 2017-02-18 15:21:10
# 12908 2017-02-18 15:21:10
